# %%
import PyPDF2
# Open the PDF file
pdf_file_path = '/Users/cej12/Skrivebord/Obama.pdf'  # Replace with the actual path to your PDF file
pdf_file = open(pdf_file_path, 'rb')

# Initialize a PDF reader object
pdf_reader = PyPDF2.PdfReader(pdf_file)

# Initialize a string to store the PDF content
text = ''

# Iterate through each page and extract the text
for page in pdf_reader.pages:
    text += page.extract_text()

# Close the PDF file
pdf_file.close()

# Assuming 'text' contains your extracted text
text = text.replace('P rague', 'Prague')
text = text.replace('go od', 'good')
text = text.replace('st atue', 'statue')
text = text.replace('i ts', 'its')
text = text.replace('estima ted', 'estimated')
text = text.replace('foll ow', 'follow')
text = text.replace('ap art', 'apart')
text = text.replace('an d', 'and')
text = text.replace('defin ing', 'defining')
text = text.replace('st ands', 'stands')
text = text.replace('nat ions', 'nations')
text = text.replace('fre e', 'free')
text = text.replace('b een', 'been')
text = text.replace('w ho', 'who')
text = text.replace('s ide', 'side')
text = text.replace('peo ple', 'people')
text = text.replace('Revolu tion', 'Revolution')
text = text.replace('pla y', 'play')
text = text.replace('con flicts', 'conflicts')
text = text.replace('cou ld', 'could')
text = text.replace('beli eved', 'believed')
text = text.replace('be come', 'become')
text = text.replace('faste r', 'faster')
text = text.replace('p ersistent', 'persistent')
text = text.replace('e asily', 'easily')
text = text.replace('fo cus', 'focus')
text = text.replace('sh ared', 'shared')
text = text.replace('t hat', 'that')
text = text.replace('com mon', 'common')
text = text.replace('impo verished', 'impoverished')
text = text.replace('dol lars', 'dollars')
text = text.replace('th e', 'the')
text = text.replace('su n', 'sun')
text = text.replace('effor t', 'effort')
text = text.replace('strengt hen', 'strengthen')
text = text.replace('Czechosl ovakia', 'Czechoslovakia')
text = text.replace('stoo d', 'stood')
text = text.replace('lif ted', 'lifted')
text = text.replace('peopl e', 'people')
text = text.replace('o f', 'of')
text = text.replace('L ondon', 'London')
text = text.replace('demons trating', 'demonstrating')
text = text.replace('th reats', 'threats')
text = text.replace('a nd', 'and')
text = text.replace('recogniz e', 'recognize')
text = text.replace('f undamental', 'fundamental')
text = text.replace('w eapons', 'weapons')
text = text.replace('ce ased', 'ceased')
text = text.replace('h as', 'has')
text = text.replace('weapo ns', 'weapons')
text = text.replace('on e', 'one')
text = text.replace('hol d', 'hold')
text = text.replace('wher e', 'where')
text = text.replace('securi ty', 'security')
text = text.replace('posse ss', 'possess')
text = text.replace('w e', 'we')
text = text.replace('21s t', '21st')
text = text.replace('U nited', 'United')
text = text.replace("Ameri ca's", "America's")
text = text.replace('g oal', 'goal')
text = text.replace('persi stence', 'persistence')
text = text.replace('t oward', 'toward')
text = text.replace('includin g', 'including')
text = text.replace('nego tiate', 'negotiate')
text = text.replace('i s', 'is')
text = text.replace('wi ll', 'will')
text = text.replace('Admi nistration', 'Administration')
text = text.replace('Compre hensive', 'Comprehensive')
text = text.replace('tofinally', 'to finally')  # Split 'tofinally' into 'to' and 'finally'
text = text.replace('bom b', 'bomb')
text = text.replace('mate rials', 'materials')
text = text.replace('sprea d', 'spread')
text = text.replace('ma terials', 'materials')
text = text.replace('No n-Proliferation', 'Non-Proliferation')
text = text.replace('th e', 'the')
text = text.replace('int ernational', 'international')
text = text.replace('breakin g', 'breaking')
text = text.replace('nucle ar', 'nuclear')
text = text.replace('acce ss', 'access')
text = text.replace('e very', 'every')
text = text.replace('peacef ul', 'peaceful')
text = text.replace('comba t', 'combat')
text = text.replace('goforward', 'go forward')  # Split 'goforward' into 'go' and 'forward'
text = text.replace('natio n', 'nation')
text = text.replace('sp read', 'spread')
text = text.replace('me an', 'mean')
text = text.replace('No w', 'Now')
text = text.replace('se curity', 'security')
text = text.replace('nation s', 'nations')
text = text.replace('communi ty', 'community')
text = text.replace('en ergy', 'energy')
text = text.replace('gov ernment', 'government')
text = text.replace('arm s', 'arms')
text = text.replace('missi le', 'missile')
text = text.replace('alli es', 'allies')
text = text.replace('again st', 'against')
text = text.replace('acqui re', 'acquire')
text = text.replace('gl obal', 'global')
text = text.replace('acros s', 'across')
text = text.replace('t o', 'to')
text = text.replace('da ngerous', 'dangerous')
text = text.replace('su chas', 'such as')
text = text.replace('Summiton', 'Summit on')
text = text.replace('Nu clear', 'Nuclear')
text = text.replace('whethe r', 'whether')
text = text.replace('acton', 'action')
text = text.replace('internationa l', 'international')
text = text.replace('setti ng', 'setting')
text = text.replace('gras p', 'grasp')
text = text.replace('m ust', 'must')
text = text.replace('to gether', 'together')
text = text.replace('st reets', 'streets')
text = text.replace('Re volution', 'Revolution')
text = text.replace('fi ring', 'firing')
text = text.replace('Humandestiny', 'Human destiny')
text = text.replace('b uild', 'build')
text = text.replace('acceptour', 'accept our')

# %%
text
# Out:
# "Thank you for this wonderful welcome. Thank you to the people of Prague. And thank you to \nthe people of the Czech Republic. Today, I am proud  to stand here with you in the middle of \nthis great city, in the center of Europe. And - to paraphrase one my predecessors - I am also \nproud to be the man who brought Michelle Obama to Prague. \n \n \nI have learned over many years to appreciate the good company and good humor of the Czech \npeople in my hometown of Chicago. Behind me is a statue of a hero of the Czech people - \nTomas Masaryk. In 1918, after America had pledged its support for Czech independence, \nMasaryk spoke to a crowd in Chicago that was estimated to be over 100.000. I don't think I \ncan match Masaryk's record, but I'm honored tofollow his footsteps from Chicago to Prague. \n \n \nFor over a thousand years, Prague has set itself apart from any other city in any other place. \nYou have known war and peace. You have seen empires  rise and fall. You have led \nrevolu
# ...

# %%
print(text)
# Out:
# Thank you for this wonderful welcome. Thank you to the people of Prague. And thank you to
# the people of the Czech Republic. Today, I am proud  to stand here with you in the middle of
# this great city, in the center of Europe. And - to paraphrase one my predecessors - I am also
# proud to be the man who brought Michelle Obama to Prague.
#
#
# I have learned over many years to appreciate the good company and good humor of the Czech
# people in my hometown of Chicago. Behind me is a statue of a hero of the Czech people -
# Tomas Masaryk. In 1918, after America had pledged its support for Czech independence,
# Masaryk spoke to a crowd in Chicago that was estimated to be over 100.000. I don't think I
# can match Masaryk's record, but I'm honored tofollow his footsteps from Chicago to Prague.
#
#
# For over a thousand years, Prague has set itself apart from any other city in any other place.
# You have known war and peace. You have seen empires  rise and fall. You have led
# ...

# %%
# Your text
text1 = text

# First split using "\n \n \n" to get 43 paragraphs
paragraphs_43 = text1.split("\n \n \n")

# Then split the last paragraph (43rd) using "\n \n" to get a total of 44 paragraphs
paragraphs_44 = paragraphs_43[:-1] + paragraphs_43[-1].split("\n \n")

# Now, paragraphs_44 contains the text split into 44 paragraphs
# You can access each paragraph using paragraphs_44[index], e.g., paragraphs_44[0] for the first paragraph

# %%
paragraphs_44[0]
# Out:
# 'Thank you for this wonderful welcome. Thank you to the people of Prague. And thank you to \nthe people of the Czech Republic. Today, I am proud  to stand here with you in the middle of \nthis great city, in the center of Europe. And - to paraphrase one my predecessors - I am also \nproud to be the man who brought Michelle Obama to Prague. '

# %%
paragraphs_44[41]
# Out:
# 'There is violence and injustice in our world that must be confronted. We must confront it not \nby splitting apart, but by standing together as free nations, as free people. I know that a call to \narms can stir the souls of men and women more than a call to lay them down. But that is why \nthe voices for peace and progress must be raised together. '

# %%
paragraphs_44[42]
# Out:
# 'Those are the voices that still echo through the streets of Prague. Those are the ghosts of \n1968. Those were the joyful sounds of the Velvet Revolution. Those were the Czechs who \nhelped bring down a nuclear-armed empire without firing a shot. '

# %%
paragraphs_44[43]
# Out:
# 'Human destiny will be what we make of it. Here, in Prague, let us honor our past by reaching \nfor a better future. Let us bridge our divisions, build upon our hopes, and accept our \nresponsibility to leave this world more prosperous and more peaceful than we found it. Thank \nyou. '

# %%
import pandas as pd
# Create a DataFrame
df = pd.DataFrame({"Text": paragraphs_44})

# Display the DataFrame
print(df)
# Out:
#                                                  Text
# 0   Thank you for this wonderful welcome. Thank yo...
# 1   I have learned over many years to appreciate t...
# 2   For over a thousand years, Prague has set itse...
# 3   When I was born, the world was divided, and ou...
# 4   We are here today because enough people ignore...
# 5   We are here today because of the courage of th...
# 6   We are here today because of the Prague Spring...
# 7   We are here today because twenty years ago, th...
# 8   We are here today because Americans and Czechs...
# 9   We share this common history. But now this gen...
# 10  None of these challenges can be solved quickly...
# 11  To renew our prosperity, we need action coordi...
# 12  To protectour planet, now is the time to chang...
# 13  To provide for our common security, we must st...
# 14  This marks the tenth year of NATO membership f...
# 15  The people of the Czech Republic kept that pro...
# ...

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Sample text
text1 = text

# Process the text with SpaCy
doc = nlp(text1)

# Extract named entities
named_entities = [(ent.text, ent.label_) for ent in doc.ents]

# Display the named entities and their labels
for entity, label in named_entities:
    print(f"Entity: {entity}, Label: {label}")
# Out:
# Entity: Prague, Label: GPE
# Entity: the Czech Republic, Label: GPE
# Entity: Today, Label: DATE
# Entity: Europe, Label: LOC
# Entity: one, Label: CARDINAL
# Entity: Michelle Obama, Label: PERSON
# Entity: Prague, Label: GPE
# Entity: many years, Label: DATE
# Entity: Czech, Label: NORP
# Entity: Chicago, Label: GPE
# Entity: Czech, Label: NORP
# Entity: Tomas Masaryk, Label: ORG
# Entity: 1918, Label: DATE
# Entity: America, Label: GPE
# Entity: Czech, Label: NORP
# Entity: Masaryk, Label: ORG
# Entity: Chicago, Label: GPE
# Entity: Masaryk, Label: PERSON
# Entity: Chicago, Label: GPE
# Entity: Prague, Label: GPE
# Entity: a thousand years, Label: DATE
# Entity: Prague, Label: GPE
# Entity: Prague, Label: GPE
# Entity: Golden City, Label: GPE
# Entity: one, Label: CARDINAL
# Entity: American, Label: NORP
# Entity: American, Label: NORP
# Entity: Prague, Label: GPE
# Entity: the Czech Republic, Label: GPE
# Entity: NATO, Label: ORG
# Entity: Europe, Label: LOC
# ...

# %%
named_entities
# Out:
# [('Prague', 'GPE'),
#  ('the Czech Republic', 'GPE'),
#  ('Today', 'DATE'),
#  ('Europe', 'LOC'),
#  ('one', 'CARDINAL'),
#  ('Michelle Obama', 'PERSON'),
#  ('Prague', 'GPE'),
#  ('many years', 'DATE'),
#  ('Czech', 'NORP'),
#  ('Chicago', 'GPE'),
#  ('Czech', 'NORP'),
#  ('Tomas Masaryk', 'ORG'),
#  ('1918', 'DATE'),
#  ('America', 'GPE'),
#  ('Czech', 'NORP'),
#  ('Masaryk', 'ORG'),
#  ('Chicago', 'GPE'),
#  ('Masaryk', 'PERSON'),
#  ('Chicago', 'GPE'),
#  ('Prague', 'GPE'),
#  ('a thousand years', 'DATE'),
#  ('Prague', 'GPE'),
#  ('Prague', 'GPE'),
#  ('Golden City', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('American', 'NORP'),
#  ('American', 'NORP'),
#  ('Prague', 'GPE'),
#  ('the Czech Republic', 'GPE'),
#  ('NATO', 'ORG'),
#  ('Europe', 'LOC'),
#  ('today', 'DATE'),
#  ('today', 'DATE'),
#  ('today', 'DATE'),
#  ('Prague', 'GPE'),
#  ('today', 'DATE'),
#  ('twenty years ago', 'DATE'),
#  ('the Velvet Revolution', 'EVENT'),
#  ('Europe', 'LOC'),
#  ('today', 'DATE'),
# ...

# %%
# Count the frequency of each entity type
entity_counts = {}
for entity, entity_type in named_entities:
    entity_counts[entity_type] = entity_counts.get(entity_type, 0) + 1

# Extract entity types and their frequencies
entity_types = list(entity_counts.keys())
entity_frequencies = list(entity_counts.values())

# Extend the entity_types list to include more types
# For example, adding 'ORG', 'DATE', 'MONEY', and 'CARDINAL'
entity_types.extend(['ORG', 'DATE', 'MONEY', 'CARDINAL'])

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.barh(entity_types, [entity_counts.get(entity_type, 0) for entity_type in entity_types], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Entity Type')
plt.title('Named Entity Frequency in Text')
plt.gca().invert_yaxis()  # Invert the y-axis to show the most frequent entities at the top
plt.show()

# %%
# Sample named entities data (replace with your actual data)
named_entities = [
    ('Prague', 'GPE'), ('Czech Republic', 'GPE'), ('Michelle Obama', 'PERSON'),
    ('Tomas Masaryk', 'ORG'), ('New York', 'GPE'), ('London', 'GPE'), ('Paris', 'GPE'),
    ('Russia', 'GPE'), ('Iran', 'GPE'), ('Al Qaeda', 'ORG'), ('North Korea', 'GPE'),
    ('The United States', 'GPE'),
    # Add more entities as needed
]

# Extract the entity names (the first element of each tuple)
entity_names = [entity[0] for entity in named_entities]

# Convert the entity names to a single string
named_entities_as_string = ' '.join(entity_names)

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(named_entities_as_string)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title('Named Entity Word Cloud')
plt.show()

# %%
import pandas as pd

# Create a DataFrame by splitting paragraphs into words
df = pd.DataFrame({"Text": paragraphs_44})
df['Words'] = df['Text'].str.split()

# Display the DataFrame
print(df)
# Out:
#                                                  Text  \
# 0   Thank you for this wonderful welcome. Thank yo...
# 1   I have learned over many years to appreciate t...
# 2   For over a thousand years, Prague has set itse...
# 3   When I was born, the world was divided, and ou...
# 4   We are here today because enough people ignore...
# 5   We are here today because of the courage of th...
# 6   We are here today because of the Prague Spring...
# 7   We are here today because twenty years ago, th...
# 8   We are here today because Americans and Czechs...
# 9   We share this common history. But now this gen...
# 10  None of these challenges can be solved quickly...
# 11  To renew our prosperity, we need action coordi...
# 12  To protectour planet, now is the time to chang...
# 13  To provide for our common security, we must st...
# 14  This marks the tenth year of NATO membership f...
# 15  The people of the Czech Republic kept that pro...
# ...

# %%
import pandas as pd
from collections import Counter

# Create a DataFrame by splitting paragraphs into words
df = pd.DataFrame({"Text": paragraphs_44})
df['Words'] = df['Text'].str.split()

# Flatten the list of words
all_words = [word for sublist in df['Words'] for word in sublist]

# Count the word frequencies
word_counts = Counter(all_words)

# Convert the word frequencies to a DataFrame for easier viewing
word_counts_df = pd.DataFrame(word_counts.items(), columns=["Word", "Frequency"])

# Sort the DataFrame by frequency in descending order
word_counts_df = word_counts_df.sort_values(by="Frequency", ascending=False)

# Display the top N words and their frequencies (e.g., top 10 words)
N = 20
print(word_counts_df.head(N))
# Out:
#         Word  Frequency
# 7        the        148
# 6         to         93
# 48       and         84
# 9         of         80
# 55         a         70
# 73      that         68
# 315       we         49
# 22        in         42
# 54        is         38
# 565  nuclear         35
# 144      our         34
# 227     will         33
# 2        for         31
# 28         -         25
# 34        be         24
# 3       this         23
# 40      have         22
# 357     must         22
# 180       We         21
# 11       And         20

# %%
import pandas as pd
from collections import Counter

# Create a DataFrame by splitting paragraphs into words
df = pd.DataFrame({"Text": paragraphs_44})
df['Words'] = df['Text'].str.split()

# Function to count word frequencies within a paragraph
def count_word_frequencies(words):
    return Counter(words)

# Apply the word frequency counting function to each row (paragraph)
df['Word Frequencies'] = df['Words'].apply(count_word_frequencies)

# Display the DataFrame with word frequencies
print(df[['Text', 'Word Frequencies']])
# Out:
#                                                  Text  \
# 0   Thank you for this wonderful welcome. Thank yo...
# 1   I have learned over many years to appreciate t...
# 2   For over a thousand years, Prague has set itse...
# 3   When I was born, the world was divided, and ou...
# 4   We are here today because enough people ignore...
# 5   We are here today because of the courage of th...
# 6   We are here today because of the Prague Spring...
# 7   We are here today because twenty years ago, th...
# 8   We are here today because Americans and Czechs...
# 9   We share this common history. But now this gen...
# 10  None of these challenges can be solved quickly...
# 11  To renew our prosperity, we need action coordi...
# 12  To protectour planet, now is the time to chang...
# 13  To provide for our common security, we must st...
# 14  This marks the tenth year of NATO membership f...
# 15  The people of the Czech Republic kept that pro...
# ...

# %%
# !pip install textblob
# Out:
# ...
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#      --------- ---------------------------- 153.6/636.8 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------  634.9/636.8 kB 8.0 MB/s eta 0:00:01
#      -------------------------------------- 636.8/636.8 kB 6.7 MB/s eta 0:00:00
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from textblob import TextBlob

# Assuming you have a DataFrame 'df' with a 'Text' column containing paragraphs
# Perform sentiment analysis on each paragraph and store the results in a new column
df['Sentiment'] = df['Text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# Visualize the distribution of sentiment scores, e.g., using a histogram
import matplotlib.pyplot as plt
plt.hist(df['Sentiment'], bins=10)
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# %%
# !pip install textstat
# Out:
# ...
#      ---------------------------------------- 0.0/105.1 kB ? eta -:--:--
#      -------------------------------------- 105.1/105.1 kB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      -------- ------------------------------- 0.4/2.0 MB 8.7 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.8/2.0 MB 8.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.4/2.0 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 10.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 9.7 MB/s eta 0:00:00
# ...

# %%
import textstat  # You may need to install the 'textstat' library

# Assuming you have a DataFrame 'df' with a 'Text' column containing paragraphs
# Calculate the Flesch-Kincaid Grade Level for each paragraph
df['Flesch_Kincaid'] = df['Text'].apply(lambda x: textstat.flesch_kincaid_grade(x))

# Visualize the distribution of Flesch-Kincaid Grade Levels
import matplotlib.pyplot as plt
plt.hist(df['Flesch_Kincaid'], bins=10)
plt.xlabel('Flesch-Kincaid Grade Level')
plt.ylabel('Frequency')
plt.show()

# %%
# Assuming you have a DataFrame 'df' with 'Text' and 'Flesch_Kincaid' columns
for index, row in df.iterrows():
    print(f"Paragraph {index + 1}:")
    print("Text:")
    print(row['Text'])
    print("\nFlesch-Kincaid Grade Level:", row['Flesch_Kincaid'])
    print("\n" + "="*50 + "\n")  # Separation line
# Out:
# Paragraph 1:
# Text:
# Thank you for this wonderful welcome. Thank you to the people of Prague. And thank you to
# the people of the Czech Republic. Today, I am proud  to stand here with you in the middle of
# this great city, in the center of Europe. And - to paraphrase one my predecessors - I am also
# proud to be the man who brought Michelle Obama to Prague.
#
# Flesch-Kincaid Grade Level: 4.7
#
# ...
#
# Paragraph 2:
# Text:
# I have learned over many years to appreciate the good company and good humor of the Czech
# people in my hometown of Chicago. Behind me is a statue of a hero of the Czech people -
# Tomas Masaryk. In 1918, after America had pledged its support for Czech independence,
# Masaryk spoke to a crowd in Chicago that was estimated to be over 100.000. I don't think I
# can match Masaryk's record, but I'm honored tofollow his footsteps from Chicago to Prague.
#
# Flesch-Kincaid Grade Level: 8.7
#
# ...
#
# Paragraph 3:
# Text:
# ...
